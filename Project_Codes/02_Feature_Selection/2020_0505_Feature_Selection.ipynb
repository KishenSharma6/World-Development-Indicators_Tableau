# %% [markdown]
# # Introduction
#
# In the following notebook, I will be subsetting features of interest from the cleaned world development indicators data set. Due to the size of the file, I will only subset a handful of features for visualization purposed in Tableau

# %% [markdown]
# **Read in libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Set notebook preferences**

# %%
###Pandas Settings
pd.set_option("display.max_columns", 2000)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# **Read in raw data**

# %%
#Set path to raw data file on local machine
path = r'C:\Users\kishe\Documents\Data Science\Projects\Tableau\Makeover Monday\World Development Indicators'

#Read in WDIData.csv and assign to df
df = pd.read_csv(path + '/Data/02_Cleaned_Data/2020_0505_Cleaned_WDIData.csv')

#Print data shape
print('Data shape:', df.shape)
# Out:
# Data shape: (15840, 1431)

# %% [markdown]
# # Data Overview

# %% [markdown]
# **Preview Data**

# %%
#Preview data
display(df.head())
# Out:
#   Country Name  Year  \
# 0  Afghanistan  1960
# 1  Afghanistan  1961
# 2  Afghanistan  1962
# 3  Afghanistan  1963
# 4  Afghanistan  1964
#
#    ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity (% of population)  \
# 0                                      NaN
# 1                                      NaN
# ...

# %% [markdown]
# Feature Selection

# %% [markdown]
# **Population**

# %%
df
